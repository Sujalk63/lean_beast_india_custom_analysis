# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\Sujal Karmakar\Desktop\Desktop\Data Analyst\Python\python_data_analytics_project\lean_beast_india_custom_analysis\scraped_data_lean_beast_india.xlsx")

df.sample(5)
# Out:
#                Username post_type   content_id       posted_time_details  \
# 977  iamleanbeast_india      Reel  C1RwQCOLJPQ  2023-12-25T13:19:26.000Z
# 245  iamleanbeast_india      Reel  DE91BtkyVqc  2025-01-18T11:58:03.000Z
# 69   iamleanbeast_india      Reel  DIxpyRAyr5f  2025-04-23T04:34:16.000Z
# 572  iamleanbeast_india      Reel  C9uLa0-tGUH  2024-07-22T10:25:36.000Z
# 373  iamleanbeast_india      Reel  DB8CzLFS421  2024-11-04T05:45:40.000Z
#
#     day_of_week  hour_of_day time_am_pm video_duration aspect_ratio  \
# 977      Monday           18   06:49 PM          00:46         9:16
# 245    Saturday           17   05:28 PM          00:37         9:16
# 69    Wednesday           10   10:04 AM          00:49         9:16
# 572      Monday           15   03:55 PM          00:13         9:16
# 373      Monday           11   11:15 AM          00:33         9:16
#
#                                           caption_text  ...  hashtags_used  \
# 977  Who said Gym Freak cant dance well i practiced...  ...             []
# 245  Comment “Roti” to receive high protein roti re...  ...             []
# 69   Common “food” and I will send you 10 Real food...  ...             []
# 572                                     Fresh Honey 🍯🍯  ...             []
# 373  Comment “Insulin” and i will send you 5 food o...  ...             []
#
#      hashtag_count all_mentions  mentions_count  \
# 977              0  ['@iamsrk']               1
# 245              0           []               0
# 69               0           []               0
# 572              0           []               0
# 373              0           []               0
#
#                                             audio_used  location  \
# 977  Pritam, Arijit Singh, Swanand Kirkire•Lutt Put...       NaN
# 245  Amit Trivedi, Madhubanti Bagchi, Amitabh Bhatt...       NaN
# 69                                            original       NaN
# 572                                           original       NaN
# 373                                           original       NaN
#
#     paid_partnership  likes_count comments_count  post_context
# 977              NaN       2077.0           79.0           NaN
# 245              NaN       2740.0         3076.0           NaN
# 69               NaN       2239.0         2052.0           NaN
# 572              NaN       1731.0           28.0           NaN
# 373              NaN       5413.0         7218.0           NaN
#
# [5 rows x 22 columns]

# %%
df.columns = df.columns.str.strip()

# %%
df["posted_time_details"].head(2)
# Out:
# 0    2025-05-19T03:10:04.000Z
# 1    2025-02-11T05:06:23.000Z
# Name: posted_time_details, dtype: object

# %%
df["formatted_posted_time_details"] = pd.to_datetime(df["posted_time_details"], utc=True, errors="coerce")
df["formatted_posted_time_details"] = df["formatted_posted_time_details"].dt.tz_convert("Asia/Kolkata")

df.drop(columns=["posted_time_details"], inplace=True)

# %%
df["posted_date"] = df["formatted_posted_time_details"].dt.date

# %%
df.head(5)
# Out:
#              Username post_type   content_id day_of_week  hour_of_day  \
# 0  iamleanbeast_india      Post  DJ0c4FlylXc      Monday            8
# 1  iamleanbeast_india      Post  DF65FG3yT-Z     Tuesday           10
# 2  iamleanbeast_india      Post  C8OUNStSKC7    Saturday            9
# 3  iamleanbeast_india      Reel  DKGgJptyiJ-      Monday            8
# 4  iamleanbeast_india      Post  DKFZihkSSQj      Sunday           22
#
#   time_am_pm video_duration aspect_ratio  \
# 0   08:40 AM            NaN          1:1
# 1   10:36 AM            NaN          1:1
# 2   09:58 AM            NaN          1:1
# 3   08:57 AM          00:59         9:16
# 4   10:38 PM            NaN          4:5
#
#                                         caption_text  caption_length  ...  \
# 0  Well done @jai.bajaj0786 lost 39kgs without co...             112  ...
# 1  ⚠️⚠️‼️TRANSFORMATION ALERT ⚠️⚠️‼️  If he keen ...             158  ...
# 2  Shredded mode on @manavkansagra1111 under my g...             123  ...
# 3  Comment “Atta” and I will send you the link of...              82  ...
# 4  Dinner Date ❤️🧿❤️🥂  #couple #love #couplegoals...             324  ...
#
#              all_mentions mentions_count  audio_used location  \
# 0                ['@jai']              1         NaN      NaN
# 1                      []              0         NaN      NaN
# 2  ['@manavkansagra1111']              1         NaN      NaN
# 3                      []              0    original      NaN
# 4                      []              0         NaN      NaN
#
#    paid_partnership likes_count  comments_count          post_context  \
# 0               NaN       443.0            17.0                   NaN
# 1               NaN       800.0            15.0          Delhi, India
# 2               NaN      1140.0            26.0                   NaN
# 3               NaN       848.0          2010.0                   NaN
# 4               NaN      2761.0            12.0  Eros Hotel New Delhi
#
#    formatted_posted_time_details  posted_date
# 0      2025-05-19 08:40:04+05:30   2025-05-19
# 1      2025-02-11 10:36:23+05:30   2025-02-11
# 2      2024-06-15 09:58:09+05:30   2024-06-15
# 3      2025-05-26 08:57:28+05:30   2025-05-26
# 4      2025-05-25 22:38:00+05:30   2025-05-25
#
# [5 rows x 23 columns]

# %%
df.dropna(subset=["likes_count", "comments_count"], inplace=True)

# %%
df.drop_duplicates(subset=['content_id'], inplace=True)

# %%
leanbeast_followers = 483000

df["engagement_like_comment"] = (df["likes_count"] + df["comments_count"]) 

df["engagement_per_1000_followers"] = (df["engagement_like_comment"] / leanbeast_followers) * 1000

df["engagement_per_1000_followers"] = df["engagement_per_1000_followers"].round(2)

# %%
import numpy as np

def parse_duration_to_seconds(duration):
    if pd.isnull(duration):
        return np.nan
    try:
        parts = str(duration).split(":")
        parts = [int(p) for p in parts]
        if len(parts) == 3:      # HH:MM:SS
            return parts[0]*3600 + parts[1]*60 + parts[2]
        elif len(parts) == 2:    # MM:SS
            return parts[0]*60 + parts[1]
        elif len(parts) == 1:    # SS
            return parts[0]
        else:
            return np.nan
    except:
        return np.nan

# Apply conversion
df["video_duration_seconds"] = df["video_duration"].apply(parse_duration_to_seconds)

df[["content_id", "video_duration_seconds"]].head(10)
# Out:
#     content_id  video_duration_seconds
# 0  DJ0c4FlylXc                     NaN
# 1  DF65FG3yT-Z                     NaN
# 2  C8OUNStSKC7                     NaN
# 3  DKGgJptyiJ-                    59.0
# 4  DKFZihkSSQj                     NaN
# 5  DKFEYgvzsIe                     NaN
# 6  DKEzSUPzGpN                    66.0
# 7  DKD_qgESuK3                    45.0
# 8  DKBvTHcS4so                    53.0
# 9  DJ_DIN2yKRN                    64.0

# %%
# # Create time period bucket
def time_period(hour):
    if 5 <= hour <= 11:
        return "Morning"
    elif 12 <= hour <= 16:
        return "Afternoon"
    elif 17 <= hour <= 21:
        return "Evening"
    else:
        return "Night"
df["time_period"] = df["hour_of_day"].apply(time_period)

# # Caption length bucket
def caption_length_bucket(length):
    if length <= 32:
        return "Very Short"
    elif length <= 75:
        return "Short"
    elif length <= 326:
        return "Medium"
    else:
        return "Long"
df["caption_length_bucket"] = df["caption_length"].apply(caption_length_bucket)

# Video duration buckets (optional)   
df["video_duration_bucket"] = df["video_duration_seconds"].apply(
    lambda x: (
        "Short" if x <= 15 else
        "Medium" if x <= 30 else
        "Long" if x <= 60 else
        "Very Long"
    ) if pd.notnull(x) else x
)
# Export final cleaned and enriched data
df.to_csv("leanbeast_analysis_ready.csv", index=False)

# %%
df.sample(5)
# Out:
#                Username post_type   content_id day_of_week  hour_of_day  \
# 43   iamleanbeast_india      Reel  DJOct1ly2qX      Sunday           14
# 528  iamleanbeast_india      Reel  C-uxDAqSmNh      Friday           17
# 88   iamleanbeast_india      Reel  DIZLVMzyLtV      Sunday           22
# 715  iamleanbeast_india      Reel  C6u7d-xS4NL    Thursday            9
# 831  iamleanbeast_india      Reel  C4jxR9fvhSp    Saturday            8
#
#     time_am_pm video_duration aspect_ratio  \
# 43    02:29 PM          00:52         9:16
# 528   05:56 PM          00:41         9:16
# 88    10:00 PM          01:14         9:16
# 715   09:22 AM          01:09         9:16
# 831   08:17 AM          00:11         9:16
#
#                                           caption_text  caption_length  ...  \
# 43   Comment, “avocado” and I will send you the rec...              76  ...
# 528                   Best indian veg protein source??              32  ...
# 88   Comment “tortilla” and I will send you the lin...             206  ...
# 715  Surprising my wife with protein waffle …… @qnt...              52  ...
# 831                                   Ye natural hai …              16  ...
#
#      comments_count post_context  formatted_posted_time_details posted_date  \
# 43           1280.0          NaN      2025-05-04 14:29:14+05:30  2025-05-04
# 528           143.0          NaN      2024-08-16 17:56:00+05:30  2024-08-16
# 88           1783.0          NaN      2025-04-13 22:00:10+05:30  2025-04-13
# 715            42.0          NaN      2024-05-09 09:22:15+05:30  2024-05-09
# 831            77.0          NaN      2024-03-16 08:17:46+05:30  2024-03-16
#
#      engagement_like_comment engagement_per_1000_followers  \
# 43                    7480.0                         15.49
# 528                   4493.0                          9.30
# 88                    8789.0                         18.20
# 715                   2654.0                          5.49
# 831                   6469.0                         13.39
#
#      video_duration_seconds time_period  caption_length_bucket  \
# 43                     52.0   Afternoon                 Medium
# 528                    41.0     Evening             Very Short
# 88                     74.0       Night                 Medium
# 715                    69.0     Morning                  Short
# 831                    11.0     Morning             Very Short
#
#      video_duration_bucket
# 43                    Long
# 528                   Long
# 88               Very Long
# 715              Very Long
# 831                  Short
#
# [5 rows x 29 columns]
